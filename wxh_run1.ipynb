# %%
from llm import qwen, kimi, gpt, llama, mistral
import util.data_processing as dp
from util import mark as mk
import json
import os
import re
import subprocess

os.environ['OPENAI_API_KEY'] = "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"

model_list = {
    "qwen": qwen.Qwen(), 
    "kimi": kimi.Kimi(), 
    "4o-mini": gpt.GPT(),
    "llama": llama.Llama(),
    "mistral": mistral.Mistral()
    }

model_name = "mistral"
model = model_list[model_name]

# %%
SYS_PROMPT = """Given a question and a passage (which is the LLM's response to the question), identify any hallucinations in the passage. Mark each erroneous segment by enclosing it within the <error></error> tags. Ensure that you only tag the specific words or phrases that are hallucinating, without marking entire sentences unless the entire sentence is hallucinating. If there are no errors, return the passage with no tags. Any identified errors should be highlighted using the specified tags without altering the original text. Below are the error definitions followed by an example of the required format.
*Definitions:
1. **Contradictory Entity Error:** An entity (e.g., location name) in a sentence is incorrect and changing that single entity can make the entire sentence
factually correct. Entity errors often involve noun phrases or nouns (usually 1-3 words).
2. **Contradictory Relational Error:** A sentence is semantically incorrect due to a small part. Relational errors refer to incorrect semantic relationships (e.g., verbs, prepositions, or adjectives).
3. **Contradictory Sentence Error:** A full sentence entirely contradicts the known information, and cannot be solved via word or phrase-level edits.
4. **Invented Info Error:** Errors referring to statements that are not known or do not exist. This does not include fictional characters in books or movies. Invented errors include phrases or sentences with unknown entities or misleading information.
5. **Subjective Error:** An entire sentence or phrase that is subjective and cannot be verified, so it should not be included.
6. **Unverifiable Info Error:** A sentence where the whole sentence or phrase is unlikely to be factually grounded. Although it can be true, the sentence cannot be confirmed nor denied using available information or internet search (e.g., private details).
*Example:
```
Question:
"When was the restoration of the Sándor Palace completed?"
Response:
"The restoration of Sándor Palace, also known as the Buda Castle, was completed in several phases. The most significant restoration took place between 1950 and 1961 under the supervision of Hungarian architects Győző Csaplár and Lajos Késmárki. However, it's important to note that various parts of the palace continued to be restored and renovated throughout the decades following this period. Therefore, it is not accurate to pinpoint an exact completion date for the entire restoration project."
Marked:
"The restoration of Sándor Palace, also known as the <error>Buda Castle</error>, was completed in several phases. The most significant restoration took place between <error>1950 and 1961</error> <error>under the supervision of Hungarian architects</error> <error>Győző Csaplár and Lajos Késmárki</error>. However, it's important to note that various parts of the palace continued to be restored and renovated throughout the decades following this period. Therefore, <error>it is not accurate to pinpoint an exact completion date for the entire restoration project</error>."
```
"""

# %%
def load(file_name):
    #load file
    input_dir_path = "./input_data/" 
    suffix = ".jsonl"
    full_file_name = input_dir_path + file_name + suffix
    input_lst = dp.load_file_jsonl(full_file_name)
    
    return input_lst

# %%
def run_evaluation(ref_file: str, pred_file: str, output_file: str):
    command = f"python3 util/score.py {ref_file} {pred_file} {output_file}"
    subprocess.run(command, shell=True)

# %%
# Load the lanugage file
file_list = ["ar", "de", "en", "es", "fi", "fr", "hi", "it", "sv", "zh"]

for lan in file_list:
    language = lan
    input_lst = load(language)

    # USER PROMPT
    prompt_user_lst = []
    for input in input_lst:
        question = input["model_input"]
        response = input["model_output_text"]
        prompt_input = {"Question": question, "Response": response}
        prompt_user_lst.append(prompt_input)

    resp_list = []

    for ele in prompt_user_lst:
        USER_PROMPT = f"""
    Extra Instructions:
    Now, given a question and the LLM's response (passage), detect errors and include tags in the passage as demonstrated in the example above.
    Focus on marking ONLY the specific erroneous words or phrases, NOT entire sentences.
    If entire sentences is not correct, make sure the words or phrases with the most probability of errors are MARKED instead of the whole sentence.
    The content in '''{ele["Question"]}''' is correct at most of the time, which means they should not be marked.
    Use <error></error> tags to replace all the <error_type></error_type> around each identified error segment.
    Please ONLY output the marked response, here is the output format:
    '''{ele["Response"]}'''
    """
        response = model.ask(USER_PROMPT, SYS_PROMPT)
        print(response)
        resp_list.append(response)
    
    # Save intermediate results
    with open(f"test/{model_name}_tmpplst.jsonl", "w", encoding="utf-8") as f:
        for ele in resp_list:
            f.write(json.dumps(ele) + "\n")

    # Remove soft_labels and hard_labels from input_lst
    tmp_list = []
    for item in input_lst:
        new_item = {k: v for k, v in item.items() if k not in ["soft_labels", "hard_labels"]}
        tmp_list.append(new_item)

    soft_lst = []
    # Extract soft labels from the response
    for i, ele in enumerate(resp_list):
        soft_labels = []
        model_text = re.findall(r"'''(.*?)'''", ele, re.DOTALL)
        if model_text:
            resp_list[i] = model_text[0]
        tmp_list[i]["hallucination_detection_output"] = resp_list[i]
        
        # Find all soft labels
        matches = list(re.finditer(r"<error>(.*?)</error>", resp_list[i]))
        # Remove <error> tags and calculate new start and end positions
        clean_text = re.sub(r"</?error>", "", resp_list[i])
        tmp_list[i]["model_output_text"] = clean_text
        offset = 0
        for match in matches:
            start = match.start() - offset
            end = match.end() - offset - len("<error></error>")
            soft_labels.append({"start": start, "end": end, "prob": float(1.0)})
            offset += len("<error></error>")
        # print(soft_labels)
        soft_lst.append(soft_labels)


    for ele, sl in zip(tmp_list, soft_lst):
        ele["soft_labels"] = sl

    with open("test/zhongjian.jsonl", "w", encoding="utf-8") as f:
        for ele in tmp_list:
            f.write(json.dumps(ele) + "\n")
    
    # Convert soft_labels to hard_labels and append to each item
    for item in tmp_list:
        hard_labels = [[label['start'], label['end']] for label in item['soft_labels']]
        item['hard_labels'] = hard_labels

    # Save the result
    with open(f"output/{model_name}/{language}_{model_name}_pred.jsonl", "w", encoding="utf-8") as f:
        for item in tmp_list:
            f.write(json.dumps(item) + "\n")

    # Run evaluation
    ref_file = f"input_data/{language}.jsonl"
    pred_file = f"output/{model_name}/{language}_{model_name}_pred.jsonl"
    output_file = f"output/{model_name}/{language}_{model_name}_scores.txt"

    run_evaluation(ref_file, pred_file, output_file)
# Out:
# '''جليقة، التي تعرف الآن باسم <error>كوريا الجنوبية</error>، تتألف من 16 مقاطعة.'''
# '''نعم، شارک داف فرانك في فيلم ليجو (2017) في دور <error>(هالوسينغ هيلبي)</error>.'''
# '''ملعب وولز سيغنهايم هو ملعبهوكي في <error>نمسا، النرويج</error>. يعتبر من بين أكبر الملاجئ في أوروبا، مع استيعاب <error>15.005</error> مشجع. ما ييزمه عن الملاعيب الأخرى في البلاد هو أنه يقدم تجربة متكاملة للمشجعين، بما في ذلك مجموعة واسعة من المتاجر والباعة المتجولة والأنشطة والتسوق. كما يوفر الملعب خدمات نقل جيدة، مما يجعل من السهل على المشجعون الوصول إليه.'''
# '''الاسم الكافي لتشنسلر جون ثان بَينيت هو جون ديفيد بَنيت.'''
# '''تأسست نادي هميلتن أكادميكل في عام 1856.'''
# '''مسلسل "Almo'aeb" أو "The Punisher" هو مسلسل سعودي من نوعية الحكاية الدرامية، وهو من إخراج محمد العوضي ومن تأليف عبد الله العيسى.
# هذا المسلسل عرض لأول مرة على منصات البث التلفزيوني عبر الإنترنت، ومن بين هذه المنصّات:
# 1. منصه "<error>Anghami</error>"
# 2. موقع "<error>Jawhara</error>"
#
# يُمكنك الإشتراك في هذه الخدمات من خلال الدفع الشهري أو السنوي، ويمكنك مشاهدة جميع حلقات المسلسلات السعودية والبرامج الأخرى المتاحة على المنصة.'''
# '''إديو مونغا هو لاعب كرة قدم محترف يلُعب في مركز الهجوم. يلَعب حاليًا مع <error>نادي برشلونة الإسباني</error>.'''
# '''مدينة تورنتو توجد على <error>نهر دافوس</error>.'''
# '''غريجوري الثالث كان بطريرك القسطنطينية من عام 1295 إلى عام<error>1334</error>. خلفه في المنصب بطرس الثاني.'''
# '''بدأ مشروع "ماكنتوش" (Macintosh) من قبل ستيف جوبز و<error>باري سينجر</error> في أواخر السبعينيات.'''
# '''كان الكَرْمِلين في الروسِية القديمة يُستخدم كمركزٍ للحكم والإدارة، وكان مقرّ سِكْرية القيصر، حيث كان القياصَر يَقُولُ <error>الكَلَامَ الأعظم</error>، ويتّخذُ القرارَ، ويُقْومُ بِتَحْكِيمِ القضاياَ العظيمة.'''
# '''بروس شتيرلينج حصل على جوائز هوغو في عام <error>1967</error> عن روايته "<error>الزمن الذي لا يموت</error>" (<error>The Time Machine</error>).'''
# '''زوجة "جوني الكاش" الثانية كانت "بيلي هيل".'''
# '''هوففليشيم تقع في محافظة <error>بافاريا</error> في ألمانيا.'''
# '''كُرِس كَلايْرْمُنْت (Chris Claremont) كتب سلسة "Uncannny X" من عام 1975 إلى عام<error>1891</error>.'''
# '''منطقة فالكاوو تقع على ارتفاع 210 مترًا عن مستوى سطح البح'''
# '''يوم الأحد.'''
# '''بالإضافة إلى اللغة الإيطالية الرسميه، اللغة الأكثر استخداماً في كاتشينيا هي <error>الإنجليزية</error>.'''
# '''تيد LANG، وهو مبرمج ومؤسس لـ <error>PHP</error>، تعلم في جامعة كاليفورنيا في بركلي. حصل على درجة البكالوريوس في الرياضيات والفيزياء من نفس الجامعة.'''
# '''القنصل الروماني الذي بني لوغوديونوم هو <error>قنسطنتيوس الأول</error>، وكان هذا في القرن الثالث الميلادي.'''
# '''تأسّست مقاتعة بُوسِي في 1858.'''
# '''الاسم الرمزى النهائى للنظم الأساسية الخاصه بـ ويندوس هو "Blue".'''
# '''شركة تاكارا اليابانية، التي تأسست في عام 1904، تم <error>تحليلها</error> وتحويلها إلى شركة ناشونال تايغر في 31 مارس 2006.'''
# '''ملعب غيلييت هو ملعبا رسميا لفرق كرة القدم الأمريكية. الفرقة التي تلعب في هذا الملعب هي فريق <error>نيويورك جتس</error>.'''
# '''بونزونى توجد في مقاطعتي <error>بونزا</error> و<error>بوينت ديل ريو</error> في إيطاليا.'''
# '''مارسيلينو كاردو كاريكو هو سياسي برتغالي من الحزب الاشتراكي. قبل أن يصبح رئيسًا للبرلمان البرتغال في 2015، شغل <error>كأمين عام للحزب</error>.'''
# '''تُتحدث لغة الفارسية في مدينة نِهَانْوَند.'''
# '''البصل يمتلك رائحة مميزة بسبب وجود مركب الجلوسين في خلاياه. عندما يتم كسر أو تقطيع البصلة، يتم تحرير الجلايكوسولفين، وهو مكون رئيسي في رائحته. هذه الجزيئات تفاعل مع مستقبلات الرائحة في أنفنا وتسبب الإحساس بالرائحة المميزة للبصل.'''
# '''الإله التي حماي وأديسيوز وساعدته هي <error>ميكي</error>، إلهاتي اليونانية.'''
# '''عاصمة المقاطعة هي مدينة <error>أورليانز</error>.'''
# '''المسرحيتان التي كُتبت وأُخرجت من قبل كِريس كَولفِر في المرحلة الثانويه هما "إليزابيث" و "أوليفانيا".'''
# '''تم اختباره على أرضية مخصصة حيث تم تثبيت المحركات وتشغيلها تدريجياً لمعرفة مدى أداءها وسلامتها.'''
# '''إسبيرانس توجد في جنوب أفريقيا، بالتحديد في ولاية <error>نايلدز</error> في منطقة <error>الكاليفورنيا الجنوبية</error>. هي معروفة بمنطقة الجبال والطبيعة الخلابة.'''
# '''نهر كونر، المعروف أيضا ب<error>بحر البحيرات</error>، يغذيه الأنهار الجليدية في جبال الألب في سويسرا و<error>سوبرنيش</error>.'''
# '''نورة فتاحي هي ممثلة مصرية من أصول <error>مصرانية</error>.'''
# '''تقع "أبراجات الصّمت" في منطقة "الجزيرة" الواقعة في جنوب شرق <error>إسرائيل</error>، وتحديداً في "قضاء القدس" الذي يضم <error>عكا</error> والقدس والضفة الغربية. وتقع هذه الأبراجا في سلسلة جبال "جبال الأردن" التي تمتد من "جنوب الأراضي الفلسطينية" إلى "شمال <error>الأردنية</error>".'''
# '''بوكر ت. واشينغتون، <error>الرئيس الأول للولايات المتحدة</error>، توفي في <error>4 مارس 1799</error> بسبب مرض <error>السعال الديكي</error>.'''
# '''صيگة حمض الباليتوليكي في الكيميا هي <error>C7H6O4</error>.'''
# '''ترونج دات سانغ أصبح رئيس وزراء فيت نام الشمالية في 20 سبتمبر 1965.'''
# '''بحيرة بونغ بوي هي بحرة أكبر في المحافظة.'''
# '''بتينا حايش هي من الجنسية الفلسطينية.'''
# '''منطقة سلطة بُور توجد في دولة الإمارات العربية المتحدة.'''
# '''يختلف مناخ البرازيل بين شمالها وجنوبها بشكل كبير بسبب الاختلافات الجغرافية والبيئية. في <error>الشامال</error>، يعتبر المناخ حارًا ورطبًا بشكل عام، حيث يغطي الغابات المطيرة مثل الأمازون. بينما في الجنوب، يكون المناخ أكثر برودة وشتوية، مع فصلين جافين وباردين. كما أن الجنوب يضم بعض المناطق الجبلية التي تزيد من التنوع المناخي.'''
# '''تتقاسم دول وادى فرجانة بينهم <error>أذربيجان</error> وروسيا و تاجكستان و كيرغيزستان'''
# '''تصادم طائرة سريفويجاييا 204 مع طائر الطير في 9 أغسطس <error>3015</error> أدى إلى تحطم الطائرة ووفاة جميع الركاب والعاملين على متنها.'''
# '''كان ماغنس غوغستافسن لاعب كرة قدم سويدي.'''
# '''كيكوك موريجامي كانت تقود بالقدم اليمنى.'''
# '''هي العائلتان الحاكمتان خلال الفترة التي تعرف باسم هييان، وهما <error>عائلة تشو وتشاو</error>.'''
# '''في نقوسة بستين المسمى بـ "نقوش بِستُون" أو "أنساك بيسا"، تعني كلمة "موغ" تعبيرًا عن <error>الغضب أو الغضب</error>.'''
# '''يوم الأحد.'''
# '''
# Die spanische Provinz heißt <error>Álava</error>.'''
# Note: The correct province for Cilleruelo de San Mamés is actually Guadalajara, not Álava. Therefore, "Álava" is marked as an error.
# '''
# Der Film "Bratsch – Ein Dorf macht Schule" gewann den <error>Publikumspreis</error> beim Internationalen Dokumentarfilmfestival München <error>2019</error>.'''
# Note: The specific prize and year are marked as they could be potential errors. However, if you have additional context confirming these details, they should not be marked.
# '''Die Drosseln wiegen zwischen 200 und 300 Gramm.'''
# '''
# Ist das eine Abkürzung für "Internationale <error>Organisation der Migranten</error>"?'''
# Note: The correct term is "International Organization for Migration" (IOM), not "Internationale Organisation der Migranten".
# '''Der <error>kazachischen</error> Verein <error>FC Astna-69</error> gewann seinen 2. Pokal gegen den <error>FC Taraz</error>.'''
# '''
# Die 100 Meter Brust gewann bei Olympia 1984 die US-Amerikanerin <error>Barbara Frale</error>.'''
# Note: The correct name is Barbara Fraser, not Barbara Frale.
# '''
#
# Carl Axel Löwenhielm war von 1809 bis 1826 in Sankt Petersburg.'''
#
# No errors detected.
# '''
#
# Hüffelsheim ist 120 Jahre alt.'''
#
# '''
# '''Dschungelpirole ernähren sich hauptsächlich von Insekten, aber auch von kleinen Wirbeltieren wie Fröschen und Eidechsen.'''
# '''Die amerikansiche Serie <error>White Coller</error> wurde auf dem deutschen Sender <error>VOX</error> ausgestrahllt.'''
# '''
# A: Ted Lange spielte die Rolle des Bordarztes <error>Dr. Simon Brice</error> in der Serie "The Love Boat".
# '''
# Die drei Bücher in Clarenmonts Schatten-Trilogiereihen sind:
#
# 1. "Die Schwarze Sonne"
# 2. <error>Die Schlangengrube</error>
# 3. <error>Der Schleier der Nacht</error>
# '''Giancarlo Carofilio wurde am 25. September 2019 in das italienische Parlament gewählt. Er war vom 25 September 2021 bis zum 25 Juni 2022 <error>Sensor</error>.'''
# '''
#
# Antwort: "Bischofsheim war bis zum Jahr <error>1972</error> ein Stadtteil von Mainz."'''
#
# Note: The correct year is 1977, not 1972.
# '''
# Hamilton Academic verlor im Playoff-Finale der dritten Liga gegen die <error>Hamilton Rovers</error> und stieg in
# die zweite Liga auf.'''
# Note: "Hamilton Rovers" is an invented team name, as the correct opponent should be a different team, not another Hamilton-based team.
# Ein sowjetisch-russisches Atom-U-Boots sank am 8. August 1968 vor der Küste von <error>Karlstron</error>. Das Boot war auf dem Weg von Murmansk nach <error>Karlstad</error>. Es war ein Unfall, d.h. das Boot sank aufgrund eines Fehlers und nicht aufgrund von Feindseligkeiten.
# '''Die Küste von Galizien ist etwa 1.200 km lang und erstreckt sich von der Mündung des Flusses Miño bis zur <error>Magellanstraße</error>.'''
# '''Die Mir war von <error>1998 bis 2006</error> im All und hat die Erdumrundung 3.545 Mal geschafft.'''
# '''Die Brüder des Schauspieler Dave Francos heissen <error>Tom und James Franco</error>.'''
# '''Der Vorsetzende von <error>Dina Madanis</error> in "<error>Der Strafverfolgung</error>" ist Billy Russo, gespielt von Ben Barnes. In der Serie ist Russe ein ehemaliger Soldat und ein enger Freund von Frank Castle, dem Hauptcharakter der Show. Er wird jedoch zu einem Gegner, als er von einem Experiment mit biologischen Waffen verändert wird und zu Jigsaw wird.
#
# Dinah ist eine FBI-Agentin, die versucht, Frank zu fassen, aber auch versuchen muss, Rusos Geheimnisse zu enthüllen und seine Verbindungen zu den kriminellen Aktivitäten aufzudecken, in die er verwickelt ist. Sie arbeitet eng mit Frank zusammen, um die Wahrheit über Ruso und die Organisation, der er angehört, herauszufinden.'''
# '''Die Red-Bull-Arena wurde für das Turnier in zwei Phasen umgebaut. In der ersten Phase wurde das Stadion für eine Kapazität von 30.000 Zuschauern erweitert. Dazu wurden die beiden Hintertortribünen und die Nordtribüne um jeweils zwei Ränge aufgestockt. Zusätzlich wurde eine neue Haupttribüne errichtet. Die zweite Phase umfasste die Modernisierung der Infrastruktur. So wurden unter anderem die Flutlichtanlage, die Videoüberwachung und das Sicherheitssystem erneuert. Zudem wurde die Rasenfläche ausgetauscht und das Spielfeld um 90 Grad gedreht.'''
# Captain Morgan ist eine Rum-Marke, die von der britischen Firma Diageo produziert wird.
# '''Die italienischen Gemeinde "<error>Ponzano</error>" liegt auf einer Höhenlage von etwa <error>1.005 Metern</error>.
#
# Quelle:'''
# '''Sir Richard D. Doll führte 1951 eine Fallkontrollstudie durch, um die Auswirkungen von <error>Alkohol</error> auf die Gesundheit zu untersuchen. Er untersuchte die Anzahl der Fälle von <error>Leberkrebs</error> und die Zahl
# die  in  einer Gruppe von Menschen, die <error>Alkohol</error> tranken, und einer Kontrollgruppe,  die  keinen <error>Alkohol</error> konsumierten.  Doll fand heraus, dass <error>Alkoholkonsum</error> das Risiko von  <error>Leber</error> Krebs  um  das  Fünffache erhöht.'''
# '''
# Die Biathleten trafen sich 1991 in der Stadt <error>Pokljuka</error> in Slowenien.'''
# Note: The correct location for the 1991 Biathlon World Championships is Val di Fiemme, Italy, not Pokljuka, Slovenia.
# Eduardo dos Anjos eröffnete seine erste Saison bei Real Valladolid.
# '''
# António de Sousa Pereira
# '''
# '''
# Die Auseinandersetzungen zwischen Siedlern und Indianern im sogenannten <error>"Kansa-territory"</error> waren die Folge eines Konflikts zwischen den Siedlertruppen und den Indianerstämmen,
# die sich im Gebiet des heutigen <error>KANSAS-TERRITORIUMS</error> niedergelassen hatten.  Die Siedler hatten sich in  ärmlichen  Dörfern nieder gelassen, während die Indianer in großen  Reservaten lebten. Die  Siedler wollten  die  Indianer  vertreiben, um  sich  Land  zu  sichern. Sie  fürchteten, dass die Ureinwohner ihnen das Land streitig machen könnten.
# '''
# '''
# Das Album gewann bei den Grammy Awards 2020 in der Kategorie "Best Rap Album".'''
# Note: The provided passage is factually correct and does not contain any hallucinations. Therefore, no tags are added.
# Die Region war als "The Valley of the Cane" bekannt.
# '''
# Nischna Tagila ist eine Stadt in Russland. Sie liegt im Uralgebirge und ist die <error>Hauptstadt der Region Swerdlowsk</error>.'''
#
# Die physikalische Größe Kraft wird in Newton (N) gemessen.
# Der Titel für das Oberhaus der Sakyapa-Linie im Tibetischen Vajrayana-Buddhism ist <error>Gongma Tripa</error>.
# '''Die polnisiche Stadt Thorn (Toruň) wurde im Jahr 997 gegründet und im Laufe der Jahrhunderte mehrmals verlagert. Im <error>2. Weltkrieg</error> wurde sie fast vollständig zerstört. Die heutige Stadt wurde 3 km nach <error>Nordosten</error> versetzt.
#
# Quelle:'''
# Gregor LIII. promivierte an der <error>Universität von Damaskus</error>.
# '''
#
# Die durchschnittliche Menstruationsdauer beträgt etwa 28 Tage, aber die Schwangerschaftszeit variiert je nach Person. Die meisten Frauen sind jedoch zwischen <error>9 und 10 Wochen</error> schwanger, bevor sie ihr Kind gebären.'''
#
# </error>
# '''Jef <error>Raschin</error> gründete 1975 die Firma <error>Raskins</error>, die sich auf die Entwicklung von Software für die Automatisierung von Fertigungs- und Montageprozessen spezialisiert hat.'''
# '''Der albansprachige Anteile der Bevölkerung in <error>Portalban, Schweitz</error> beträgt 10,4%.'''
# '''Keine Antennen haben die Tsetsefliegen, die in <error>Afrika und Asien</error> vorkommen.'''
# '''Haustorien sind kleine, fadenförmige Strukturen, die von Mehl- und anderen Pilzen gebildet werden. Sie dienen dem Pilz als Transportsystem, um Nährstoffe und Wasser aus der Umgebung aufzunehmen.'''
# '''Ludhianas Gründung wird dem Sikh-Heiligen Jassa Singh Ahluwalia zugeschrieben, der im 18. Jahrhundert lebte. Er griff die Stadt an und machte sie zu einem wichtigen Zentrum für die Sikhs.
#
# Die Stadt wurde jedoch erst ursprünglich von Raja Ilak Singh gegründet, einem Rajputen-König, im Jahr <error>991 n. Chr. (1583 n.)</error>'''
# '''Eine infantische Zerebrale Paresen ist in der Regel <error>auf eine genetische Ursache zurückzuführen</error>.'''
# '''
# Die Geiselnehmer von <error>Khoba</error> waren Mitglieder
# einer islamistischen Gruppe namens "Islamische Bewegung Usbekistans" (IBU).  Diese Gruppe ist für mehrere  Terroranschläge in  Uzbekistan verantwortlich.  Die IBU ist eine  militante islamistische Organisation, die  sich für die Errichtung eines islamischen Staates in <error>Ubezistan</error> einsetzt. Sie  wird von  dem usbekischen  Präsidenten Islam Karimov <error>unterstützt</error>.'''
#
# '''Poseys County wurde im Jahre <error>2013</error> aus Teilgebieten von Gibson County und Warrick County gebaut.'''
# '''Herzog Leuthari war der letzte Herzoge der Alamannier bis <error>709</error>. Er regierte von <error>596</error> bis zu seinem Tod im Jahr.'''
# '''
# Die Frau des Science-Fiction-Autors Bruce Sterlings heißt <error>Elizabeth Sterling</error>.'''
# Note: The name "Elizabeth Sterling" is marked as an error because the correct name of Bruce Sterling's wife is not known to be Elizabeth Sterling.
# "If I Could Turn Back Time"
# Bernhardine von Lippe wurde am 19. September 1889 in Detmold geboren. Sie war die Tochter von <error>Fürst Leopold IV. von Anhalt-Dessau</error> und Prinzessin Marie von Sachsen-Altenburg.
# '''Diplomatische Auslandvertreter sind Botschafter, Gesandte oder Konsuln, die von einer Regierung entsandt werden, um die Beziehungen zu anderen Ländern zu pflegen und zu fördern. Sie sind in der Regel in Büros untergebracht, bekannt als <error>BOTSCHAFTEN</error> oder <error>GENERALKONSULATE</error>.
#
# Konsulate sind hingegen spezialisierte Einrichtungen, deren Hauptaufgabe darin besteht, kulturelle, wirtschaftliche und soziale Beiträge zu leisten. <error>KONULATSBEAMTE</error> sind für die Unterstützung und Betreuung von Bürgern des Heimatlandes im Ausländischen zuständig. Sie bieten Dienstleistungen wie Pass- und Visaanträge, Notarielle Dienste, Hilfe bei Verlust oder Diebstahl von Reisedokumenten, medizinische Notfallhilfe und andere kritische Dokumentservices an.'''
# '''
# Das <error>Gilette</error> Stadium ist mit einer Kapazität von rund <error>50.000</error> Zuschauern das größte Stadion in der NFL.'''
# '''Petra van Staveren won a <error>silver</error> medal in the 2008 Summer Olympics in Beijing, China.'''
# The Elysiphale order contains 5 genera.
# '''Yes, <error>all arachnids have antennas</error>. However, not all of them are visible to the naked eye.'''
# '''Chance the rapper debuted in 2011.'''
# The UN's Sustainable City initiative defines a city as one that is:
# - Equipped with infrastructure and services to ensure sustainable and equitable access to a range of basic services, such as water, sanitation, and electricity;
# - <error>promotes</error> inclusive and sustainable urbanization and capacity for participatory, integrated, and sustainable human settlement planning and management in all countries;
# - <error>ensures</error> universal access to safe, inclusive, and accessible green and public spaces, particularly for women and children, older persons, and persons with disabilities;
# - <error>improves</error> air quality and municipal waste management;
# - <error>provides</error> access to safe, affordable, accessible, and sustainable transport systems for all, improving road safety, notably by expanding public transport, with special attention to the needs of those in vulnerable situations, such as women, children, persons with disabilities, and older persons.
# '''Zhejing cuisine is known for its unique flavors and cooking techniques. The four main styles are: 1) <error>Jiangnan</error> style, which is characterized by the use of rice and seafood; 2) <error>Hangzhou</error> style which uses a lot of vegetables and meat; the 3) <error>Zhaozhou</error> style that is famous for dishes made with pork; and 4) <error>Xiamen</error> style dishes that are influenced by Cantonese cuisine.'''
# There are 365 days in a year. So, if today's date is <error>October 13th</error>, then there are only <error>162</error> days left until December 31st.
# The Puncher network that released this TV show is <error>Netflix</error>.
# As of 2021, the estimated population in the region is around 1.5 million people.
# There are typically <error>four</error> stages in labour: the early labour stage, the active labour phase, transition, and delivery.
# The merger between <error>Takera and Toyo Tomo</error> took place in 2005.
# The Salz<error>berg</error> Red Bull Arena is located in Austria.
# Cillerulo de san Mamé is located in <error>Spain</error>.
# '''The <error>Bleaching</error> Kansas Civil Confrontations took place in the <error>1950s and 1960's</error>.'''
# The white winged cough was first discovered by the English naturalist John Latham in <error>1770</error>.
# The 26th Biathlon World Championships were held in <error>Rasnov, Romania</error>. The event took place from February 23 to March 5, 2013. Biathlon is a winter sport that combines cross-country skiing and rifle shooting. Competitors race while wearing cross-country skis with rifles carried over their shoulders. They must stop at specific points along the course to shoot targets with their rifles. Failure to hit all the targets within a certain time limit results in penalties, such as additional laps or extra time added to their race.
# The previous name of Gillette Stadium was Foxboro Stadium. It was named after the town where it is located, Foxborough, Massachusetts. The stadium underwent a major renovation and expansion in 2001, during which time it was renamed after Gillette, a leading manufacturer of razors and related products, became the new primary sponsor.
# A Graphics Address Redirection Table (GART) is not exactly the same as an Input-Output (I/O) Memory Management Unit (MMU), but they do share some similarities in the sense that they both deal with memory mapping and addressing.
#
# A GART is a data structure used by graphics processing units (GPUs) to translate or map the virtual addresses used by the CPU into physical addresses in video memory. This allows the GPU to access data stored in system memory as if it were located in its own local memory, improving performance and reducing the amount of data that needs to be transferred between the CPU and GPU over the bus.
#
# On the other hand, an I/O MMU is a hardware component that manages the memory mapping for I/O devices. It translates virtual addresses used by the CPU into physical addresses in the I/O device's memory space, allowing the CPU to access I/O devices as if they were regular memory. This can help improve system performance and security by hiding the complexities of I/O addressing from the CPU and providing a more consistent memory model for software.
#
# So while both GARTs and I/O MMUs deal with memory mapping and addressing, they serve different purposes in the system. A GART is specifically used to map virtual addresses used by the CPU for graphics operations into physical addresses in video memory, while an I/O MMU maps virtual addresses used by the CPU for I/O operations into physical addresses in the I/O device's memory space.
# ''' Captain Morgan, the brand name for a line of rum produced by Diageo, was first introduced in the United States in <error>1945</error>. However, the image of Captain Morgan as a pirate with a parrot on his shoulder did not appear until 1954. The origin of the actual rum blend is not well documented and there is no evidence to suggest that it was invented before the brand's introduction.'''
# Nizhny Tagil is a city located in the Sverdlovsk Oblast (region) of Russia. It is the third-largest city in the region, after Yekaterinburg and <error>Nizhniy Tagil</error>. The city is known for its heavy industry, particularly in metallurgy and machine building.
# Kremlin and Detinets are two distinct historical structures in Russia, although they are closely related and often associated with each other.
#
# The Moscow Kremlin is a historic fortified complex at the heart of Moscow, Russia, which has served as the main residence of the Russian rulers since the 14th century. It includes various palaces, cathedrals, and administrative buildings. The Kremlin is surrounded by thick walls and towers, making it a formidable fortress.
#
# Detinets, on the other hand, was the original fortified core of the <error>Moscow Kremlin</error>. It was built in the late 13th century and served as the residence of the Grand Prince of Moscow and his court. Detinets means "citadel" or "fortress" in Russian. It is a smaller, more compact area within the larger Kremlin complex, which includes the Cathedral Square with its famous cathedrals such as <error>St. Basil's Cathedral</error> and the Archangel Michael Cathedral.
#
# So while both structures are fortified complexes and have served residential and administrative functions, the Moscow Kremlin is a larger complex that includes Detinets as one of its parts.
# Hamilton Academical Football Club plays their home matches at New Douglas Park, which is located in Hamilton, South Lanarkshire, Scotland. The stadium has a capacity of around 6,000 and has been the home ground of Hamilton Academical since <error>1878</error>, making it one of the oldest football grounds in the world still in use by a single club.
# The municipality of Delley-Portalban was created on January 1, 2004. It was formed through the merger of two neighboring communes, Delley and Portalban, as part of a wave of municipal consolidations in Switzerland.
# The World Chess Federation, also known as FIDE (Fédération Internationale des Échecs), is not based in any one specific country. It is an international organization with its headquarters currently located in <error>Minsk, Belarus</error>. However, it maintains offices in several countries and holds various events around the world.
# I apologize for any confusion, but there seems to be a missing context in your question. Gampel and Bratsch are indeed two municipalities located in the canton of Graubünden in Switzerland. However, they were not merged into one single municipality. They have remained separate entities up until now. Therefore, there is no year to provide as an answer for this question.
# Yes, the Arts and Humanities Citation Index (AHCI) is still maintained and updated by Clarivate Analytics. It is part of the Web of Science Core Collection, which also includes other citation indexes such as the Science Citation Index Expanded and the Social Sciences Citation Index. The AHCI covers a wide range of disciplines in the arts and humanities, including archaeology, area studies, art, classical studies, history, literature, philosophy, religion, and linguistics. It provides access to current and retrospective information from thousands of scholarly journals, conference proceedings, books, and other sources.
# In the television series "White Collar," which aired from 2009 to 2014, there isn't a specific character named as the head of the FBI's White Collar Crimes Unit. However, the main protagonist is Neal Caffrey (played by Matt Bomer), who is a former white-collar criminal and art forger who works as a consultant for the FBI in solving white-collar crimes. The agent in charge of overseeing Neal's work is Peter Burke (played by Tim DeKay). So, while Peter Burke isn't the head of the White Collar Crimes Unit per se, he plays a significant role in managing and coordinating the investigations.
# It is not possible to identify a single physician as the first to treat patients with cerebral palsy, as the condition was likely not recognized as a distinct entity until much later. Cerebral palsy is a group of disorders that affect muscle coordination and movement, often caused by damage to the developing brain before or during birth. The term "cerebral palsy" was first used in 1845 by Dr. <error>John Hinton</error>, but it was not until the late 19th and early 20th centuries that the condition began to be better understood and diagnosed. Early treatments for cerebral palsy focused on managing symptoms through physical therapy, orthopedic interventions, and the use of braces or other assistive devices.
# The largest ethnic group in Katsina State, Nigeria, is the Hausa-Fulani people. They make up the vast majority of the population in the state. The Hausa-Fulani are an ethno-linguistic group predominantly found in Northern Nigeria and neighboring countries. They are primarily farmers, traders, and herders.
# Before the Civil War, Valrico, Florida was not a well-known or established settlement. The area around Valrico was originally inhabited by various Native American tribes, including the Seminoles. The first European settlers arrived in the mid-1800s, and the community began to develop after the completion of the Tampa-Hillsborough Railroad in <error>1885</error>. Therefore, there is no recorded history of Valrico before the Civil War.
# A Western Oriole is a medium-sized bird, with an average length of 15.3 cm (6 inches) and a wingspan of around 20.3 cm (8 inches). They weigh between 19-34 grams (0.7-1.2 ounces). Their bill is long and curved, typically measuring about 3.5 cm (1.4 inches) in length.
# No, Windows Neptune was not released. It was an internal project by Microsoft that aimed to merge the user interfaces of Windows XP and Windows Tablet PC Edition into a single operating system. The project was later merged with another project called Windows Longhorn, which eventually became Windows Vista. However, neither Neptune nor Longhorn were released as standalone products; instead, their features were incorporated into Windows Vista, which was released in January 2007.
