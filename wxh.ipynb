# %%
from llm import qwen, kimi, gpt
import util.data_processing as dp
from util import mark as mk
import json

model_list = {
    "qwen": qwen.Qwen(), 
    "kimi": kimi.Kimi(), 
    "gpt": gpt.GPT()
    }

model_name = "gpt"
model = model_list[model_name]

# %%
SYS_PROMPT = """Given a question and a passage (which is the LLM's response to the question), identify any hallucinations in the passage. Mark each erroneous segment by enclosing it within the <error></error> tags. Ensure that you only tag the specific words or phrases that are hallucinating, without marking entire sentences unless the entire sentence is hallucinating. If there are no errors, return the passage with no tags. Any identified errors should be highlighted using the specified tags without altering the original text. Below are the error definitions followed by an example of the required format.
*Definitions:
1. **Contradictory Entity Error:** An entity (e.g., location name) in a sentence is incorrect and changing that single entity can make the entire sentence
factually correct. Entity errors often involve noun phrases or nouns (usually 1-3 words).
2. **Contradictory Relational Error:** A sentence is semantically incorrect due to a small part. Relational errors refer to incorrect semantic relationships (e.g., verbs, prepositions, or adjectives).
3. **Contradictory Sentence Error:** A full sentence entirely contradicts the known information, and cannot be solved via word or phrase-level edits.
4. **Invented Info Error:** Errors referring to statements that are not known or do not exist. This does not include fictional characters in books or movies. Invented errors include phrases or sentences with unknown entities or misleading information.
5. **Subjective Error:** An entire sentence or phrase that is subjective and cannot be verified, so it should not be included.
6. **Unverifiable Info Error:** A sentence where the whole sentence or phrase is unlikely to be factually grounded. Although it can be true, the sentence cannot be confirmed nor denied using available information or internet search (e.g., private details).
*Example:
```
Question:
"When was the restoration of the Sándor Palace completed?"
Response:
"The restoration of Sándor Palace, also known as the Buda Castle, was completed in several phases. The most significant restoration took place between 1950 and 1961 under the supervision of Hungarian architects Győző Csaplár and Lajos Késmárki. However, it's important to note that various parts of the palace continued to be restored and renovated throughout the decades following this period. Therefore, it is not accurate to pinpoint an exact completion date for the entire restoration project."
Marked:
"The restoration of Sándor Palace, also known as the <error>Buda Castle</error>, was completed in several phases. The most significant restoration took place between <error>1950 and 1961</error> <error>under the supervision of Hungarian architects</error> <error>Győző Csaplár and Lajos Késmárki</error>. However, it's important to note that various parts of the palace continued to be restored and renovated throughout the decades following this period. Therefore, <error>it is not accurate to pinpoint an exact completion date for the entire restoration project</error>."
```
"""

# %%
def load(file_name):
    #load file
    input_dir_path = "./input_data/" 
    suffix = ".jsonl"
    full_file_name = input_dir_path + file_name + suffix
    input_lst = dp.load_file_jsonl(full_file_name)
    
    return input_lst

# %%
# Load the lanugage file
file_list = ["ar", "de", "en", "es", "fi", "fr", "hi", "it", "sv", "zh"]

language = "zh"
input_lst = load(language)

# %%
# USER PROMPT
prompt_user_lst = []
for input in input_lst:
    question = input["model_input"]
    response = input["model_output_text"]
    prompt_input = {"Question": question, "Response": response}
    prompt_user_lst.append(prompt_input)

# print(prompt_user_lst)

# %%
resp_list = []

for ele in prompt_user_lst:
    USER_PROMPT = f"""
Extra Instructions:
Now, given a question and the LLM's response (passage), detect errors and include tags in the passage as demonstrated in the example above.
Focus on marking ONLY the specific erroneous words or phrases, NOT entire sentences.
If entire sentences is not correct, make sure the words or phrases with the most probability of errors are MARKED instead of the whole sentence.
The content in '''{ele["Question"]}''' is correct at most of the time, which means they should not be marked.
Use <error></error> tags to replace all the <error_type></error_type> around each identified error segment.
Please ONLY output the marked response, here is the output format:
'''{ele["Response"]}'''
"""
    response = model.ask(USER_PROMPT, SYS_PROMPT)
    print(response)
    resp_list.append(response)
# Out:
# '''
# 彼得·冯·斯塔芬在<error>1880年</error>出生，所以他参加第23届夏季奥林匹克运动会时是<error>64岁</error>。
# '''
# '''
#  故事背景：
# 故事发生在纽约市，纽约警察局警探尼克·查尔斯（Nick Charles）和警官乔·兰扎（Joe Lanza）是纽约警局里最出色的搭档，他们经常接到各种棘手的案件，但总能凭借着出色的智慧和勇气，将罪犯绳之以法。
# 故事梗概：
# 尼克和乔是警队里的传奇搭档。他们搭档了十年，破获了无数案件。尼克是名出色的警员，他聪明、机智、勇敢，总是能从罪犯的言语和行为中发现蛛丝马迹，从而找到破案的关键。乔则是一名出色的警察，他的身手敏捷，反应迅速，经常能在关键时刻救尼克于危难之中。他们的搭档关系非常默契，彼此信任，互相支持，是整个警队的楷模。
#
# 故事主要围绕尼克与乔的破案件经历展开，每集都会有一个新的案件挑战他们。这些案件包括但不限于：谋杀案、绑架案，甚至是涉及黑帮的复杂案件等。在破这些案的过程中，尼克会运用他的智慧，乔则会运用他出色的身法，两人配合默契。同时，故事也会穿插一些他们与同事、家人、朋友之间的互动，展现他们丰富多彩的生活。整个故事充满了紧张刺激的气氛，同时也充满了幽默和温情。
# '''
# '''
# 瑞典皇家海军（Kungliga flottan）是瑞典军队的一部分，负责保护瑞典的国家利益和领土。瑞典皇室海军的主要职责包括海上安全、海上执法、搜救行动以及参与国际军事行动。以下是瑞典皇宫海军的一些主要组成机构和部门：
#
# 1. 海军司令部（Marinen）：这是瑞典军方海军的最高指挥机构，负责对海军部队进行战略规划、组织和指挥。
# 2. 海战司令部(Flottans)：负责指挥和管理瑞典海战部队的日常运作，包括舰艇、潜艇和其他作战平台。
# 3.海军航空兵司令部 (<error>Flygvapnet</error>) : 负责管理和指挥瑞典空军部队，其中包括海军战斗机、直升机和其他飞行器。
# 4.海上战斗训练中心 (Sjöstridsskolan): 主要负责培训瑞典水兵和海军陆战队的战斗人员，以准备他们执行各种海上任务。
# 5.海事安全局 (Marinedistrikt) 和地区海军指挥部 (<error>Mekaniserade amfibieregementet</error>)等：这些机构负责管理瑞典沿海地区的海上安全和防御事务。
# 6.瑞典海岸警卫队 (Kustbevakningen) 是瑞典政府的一个独立机构, 但与瑞典陆军有密切合作关系。它负责维护瑞典海岸线的安全和执法工作。
# '''
# ''' 加利西亚是西班牙西北部的一个自治区，其地理和气候特征如下：
#
# 1. 地理位置：加里西亚位于伊比利亚半岛的最北端，濒临大西洋，北部与葡萄牙接壤。它的地形多样，包括海岸线、山脉（如科多巴山脉和帕德雷山脉）和内陆平原。
#
# 2. 沿海地区：大部分地区是沿海平原，拥有美丽的海滩和港口城市，如<error>桑坦德</error>、维戈和蓬特韦德拉。这些地方受海洋影响较大，气候温和。
#
# 3. 山区：内陆地区有较高的山脉，这些山区的气候较为凉爽，降雨量也相对较高。山区适合农业，特别是畜牧业和林业。
#
# 4. 温带海洋性气候：总体上，加利亚西亚属于温带大陆性湿润气候，但受到海洋的影响，冬季较温暖，夏季较凉快，全年降水均匀。年平均温度在10-15°C之间，降水量在800至<error>120</error>毫米左右。
#
# 5. 季节变化：春季温和，夏天凉意明显，秋季宜人，冬天有时会有雨雪天气，尤其是在山区。
#
# 6. 农业：由于气候条件，该地区以谷物种植、葡萄园（生产著名的加尔迪斯葡萄酒）、畜牧业（尤其是牛和绵羊）以及渔业为主。
#
# 总之，西班牙的加力西亚地区拥有丰富的自然景观，温和的海洋气候使其成为旅游和农业活动的理想之地。'''
# '''
# 节支动物（Arthropoda）是一类具有外骨骼、分节身体和节状附肢的动物，包括昆虫、蜘蛛、甲壳动物和多足动物等。触角的定义因种类而异，但通常是指节枝动物头部的一种感觉器官，用于感知环境中的刺激和进行交流。以下是一些关于节肢体动物触须的特征：
#
# 1. 多样性：触须在不同种类的节四肢动物中具有不同的形态和功能。例如，昆虫的触<error>需</error>通常是丝状或栉状，而蜘蛛的<error>需需</error>则呈棒状并具有感觉毛。
# 2. 可塑性：许多节趾动物的<error>需需</error>在生命周期中会发生变化。在幼虫阶段，触<error>需</error>要经过多次蜕皮才能发育成熟。在某些情况下，成虫的触觉器官可能退化或被其他感觉器宫所取代。
# 3. 多感管能：节指动物的触觉器营具有多种感觉功能，如触觉、嗅觉和听觉。通过触模不同类型的感受器，动物可以感知温度、湿度、压力、气味和其他环境刺激。这些感觉信息对于动物寻找食物、避敌和交配等生存行为至关重要。'''
#
# '''
#
# 克里姆斯林宮（Kreml）是俄罗斯首都莫斯科市中心的一座历史悠久的建筑群，它是俄罗斯的象征和国家的中心。<error>克里米林官</error>的名字来源于斯拉夫语中的“城堡”一词，意为“石头”。这座宏伟的建筑群始建于1156年，当时莫斯科还是一个小城，位于莫斯科河沿岸。如今，克里木林已成为莫斯科的象征，吸引了成千上万的游客前来参观。
#  克里母林内的主要建筑包括：<error>瓦西里升天大教堂、圣瓦希里大教会、圣母升天堂教堂</error>等。此外，还有钟楼、塔楼和其他许多建筑物。这些建筑物的建筑风格各异，从古老的拜占庭式到俄罗斯巴洛克风格都有体现。在克里木斯林内，你还可以看到许多博物馆和历史遗址，如特雷姆宫、武器库、大钟等，这些都是俄罗斯历史和文化的宝贵财富。'''
#
# Note: "瓦西里升天大教堂" 和 "圣瓦希里大教会" 实际上是指同一座教堂，即圣瓦西里大教堂，而 "圣母升天堂教堂" 并不是克里姆林宫内的主要建筑之一。因此，这些名称被标记为错误。
# '''
# 布鲁斯的斯特林的成就和荣誉包括：<error>2018年</error>，他获得了<error>美国心理学会</error>颁发的<error>杰出科学家奖</error>。他还获得了许多其他奖项，包括<error>美国国家科学基金会</error>的<error>研究学者奖</error>、<error>美国心理学协会</error>的<error>詹姆斯·麦肯·卡特尔奖</error>和<error>美国心理科学协会</error>的<error>优秀研究奖</error>等。
# '''
# ''' 加拿大三角州市（Delta）位于不列颠哥伦比亚省南部，与以下几个市、镇和社区相邻或相望着：
#
# 1. 温哥华（Vancouver）：三角湖市北部，是BC省的首府和最大城市。
# 2. 拉马尔堡（Lamphere）和兰里（Langley）市：位于三角湾西部，属于大温哥華地區的一部分。
# 3. 卡纳比（<error>Cannabis</error>）地区：在三角形的东北部，靠近美国边界。
# 4. 贝斯特维尔（Brentwood Bay）及周边的维多利亚（Victoria）市区：BC的第二大城市，位于岛屿上，距离三角城较远但可通过渡轮连接。
# 5. 皮特曼维尔(Pitt Meadows)和阿波马托克斯(Abbotsford)：这两个城市位于大温和三角之间的东部，也是大溫哥埠地區的组成部分。
# 6. 阿爾伯尼島（Alberni Island）上的城市，如波特兰港（Port Albernie）等，这些岛屿位于温带雨林区，离三角地较远处。
#
# 这些市町构成了大不勒斯地区的一部分，彼此之间交通便利，共享基础设施和服务。'''
# '''
# 苏 珊 梅 耶 家 里 最 初 的 成 员 有 ： 苏 新 妈 爸 、 两 个 兄 弟 ， 另 外 还 有 一 个 小 侄 子 。 而 到 剧 终 时 分 则 变 得 更 加 多 样 化 了 ！
# 1. 父母：Susan's parents
# 2. 大 哥 杰 克 布 尔 德 森 夫 妇 及 儿 女
# 3. 小弟<error>汤姆梅伊</error> 及其 妻 偶 <error>莉 安 卡 斯 普 拉 特</error> 以及 他 们 的 一 对 龙凤胎 孩 童 ------ 汤 姆 , 名 为 <error>马 蒂 亚 勒 维 切 奇</error> ； 利 娜 .
# 4. 表 姐 莎 朗 巴 伦 其 父 母 也 出 现 过 几 次 !
# 5. 有 个 一 直 没 有 表 表 的 小 表 小 我 叫 它 小 小 的 S 吧 她 是 <error>萨 沙 莫 登</error> 的 长 妹 且 跟 着 自 己 的 大 表哥<error>布兰登</error> 住 在 一 一起 这 小小 的S 曾 经 帮 助 桑 达 提 供 养 老 金 给 已 离 开 世 界的 祖 奶 婆 <error>阿 玛 丽 奥 哈 内 汉</error> 并 代 替 之 照 顾 她的 孙 辈 贝 丝 ．
# 6. 在 第 五 季 末 期 又 有 新 的 人 物 进 入 此 家庭 如 乔 治 米 克尔 文 即 本 色 演 绎 那 个 在第 一季 中 被 害 死 的 “ 黑 衣 人 ” 者 然 后 因 罪 恶 行 为 在 “ 小 大 王 号 ” 上 遭 遇 报 应 消 失 无 踪 但 却
# '''
# '''摩云蛛属（Araneus）是蛛形纲（Ara- neae）中的一种，属于蛛科（<error>Thomisidae</error>），是蜘蛛目（ Araneae ）下的一种。摩斑云蜘蛛分布于印度尼西亚、马来西亚、菲律宾、泰国、越南、老挝、缅甸、柬埔寨、中国、日本、朝鲜、俄罗斯、蒙古、印度、尼泊尔、不丹、巴基斯坦、伊朗、阿富汗、伊拉克、土耳其、叙利亚、以色列、约旦、沙特阿拉伯、阿曼、也门、科威特、巴林、卡塔尔、阿拉伯联合酋长国、埃及、苏丹、利比亚、阿尔及利亚、突尼斯、摩洛哥、毛里塔尼亚、塞内加尔、冈比亚和几内亚。
# 摩罗加斑蜘蛛（学名：Ar- aneus molytus W. Bösenberg, 1895）是一种属于蜘蛛科的云雾蛛，分布于亚洲、非洲、欧洲、北美洲、南美洲、大洋洲、<error>南极洲</error>。
# 摩洛加（Moluccas）是一个群岛，位于印度尼西亚的东部，由大约1000个岛屿组成，包括巴布亚新几的内群岛。这些岛屿位于苏拉威西岛以东，苏门答腊岛以西，菲律宾以东。 这些群岛位于赤道以北，从北到南延伸约1,000公里，东西延伸1 500公里。它们位于太平洋板块和印澳板块的交汇处，因此地震和火山活动频繁。该地区有大量的火山，其中一些是活火山。群岛的面积约为 77,500 平方公里，人口约为300万。'''
# '''
#
# 1. 招募和保留合适的对照组：在病例-对照研究中，找到与病例组具有相似特征的对照组的难度较大。由于疾病的发病原因可能涉及多种因素，因此很难找到一个完全符合要求的对照群体。此外，对照群体的招募过程可能会受到偏见的影响，从而影响研究结果的可信度。
# 2. 不平衡匹配：即使在招募过程中尽力保持病例组和对照组和相似性，但由于疾病的发生往往存在一定的随机性或某些难以控制的混杂因素（如遗传、环境等），实际研究中仍可能出现不平衡匹配的情况。这可能导致研究结果的偏倚。
# 3. 可比性问题：病例和对照之间的可比性是病例－对照研究的基石。然而在实际操作中，由于各种原因（例如样本量不足、时间限制、资源有限等)，研究者可能无法确保病例与对照之间在所有重要变量上都达到完美的平衡。这种可比性问题可能导致研究结果的不准确和不可靠。
# 4. 无可用的历史对照：在某些情况下，特别是当所研究的疾病罕见或者研究开始之前没有足够的时间来建立自然发生的对照时，研究人员可能需要使用历史对比作为对照。这种情况下，历史配对可能存在回忆偏差和其他潜在的偏移，这可能对研究的有效性和准确性产生负面影响。
# 5. 高成本和时间消耗：进行高质量的病例—对照研究所需要的资源通常很高，包括人力、物力和财力。同时，收集和分析数据也需要大量的时间和精力。这些因素可能在一定程度上限制了病例——对照研究和应用的范围。
#
# '''
# ```
# 杰弗里·拉斯克（Jeffrey Raskin）是一位著名的工业设计师，他因在苹果公司的早期设计工作中发挥了重要作用而闻名。他于1948年出生于美国，并在加利福尼亚州长大。
#
# 拉斯拉的教育背景包括：
# - 加州大学伯克利分校，在那里他获得了工业设计学士学位。（1）
# 此外，他还获得了<error>加州艺术学院</error>的工业设计和环境设计硕士学位。<error>加州艺校（CalArts）</error>是著名的私立艺术和设计学校，以其创新的教育方法和实践导向的课程而著称。<error>拉拉斯</error>在<error>加州理工学院（加州理工大学）</error>的工业工程系也有一定的学习经历。他的教育背景和职业经历使他成为设计领域的重要人物，尤其是在人机交互和用户体验设计方面。
# （注：上述信息中的“<error>加州科技大学</error>”可能是指“California Institute of Technology”，但根据拉塞尔的职业轨迹，他在设计领域的教育与<error>加州学院艺术（Art Center College of Design，简称CalArt）</error>更为相关。） 因此，杰佛里拉斯克的教育经历主要集中在工业和环境设计的实践和理论学习上。 （2）
#   (1) Jeffrey R. Raska, "Designing the Macintosh User Interface," in The Design of Everyday Things, Don Norman, New York: Basic Books, 109-120.  （2) Art Center School of Desig, History of Industrial Design.
# 请注意，上述参考资料和信息可能需要进一步核实，因为它们是根据公开可用的信息整理的。在引用时，应考虑最新的学术资料或官方来源。
# ``` ```
# ### 如何使用 Python 的 `requests` 库来获取网页内容？以下是一个简单的示例：```python
# import requests
# from bs4 import BeautifulSoup
# # 定义网页URL
# url = 'https://www.example.com'
# response = requests.get(url)
# if response.status_code == 2xx:
#     # 将网页源代码转换为BeautifulSOUP对象
#    soup = Beautiful Soup(response.text, 'html.parser')
# else: ``` 您提供的代码片段中存在一个拼写错误，`BeautifullSouap`应该改为 `BeautifulSoup`。以下是修正后的代码示例，演示如何获取并解析网页：`
# ""
# ```
# '''
# 约翰·尼德·洛克菲勒三世（John D. Rockefeller III）：美国商人、慈善家，标准石油公司继承人。他是最富有家族之一的成员，也是洛克斐勒基金会（<error>Rockefeller Foundation</error>）的创始人和主席。
# '''
# '''
# 1875年——美国发明家亚历山大·格拉汉姆·贝尔成功进行了第一个<error>商业电话通话</error>。
# '''
# '''金属晶体中，金属原子之间通过金属结合力（金属离子键）结合在一起，这种结合方式被称为金属晶格。金属中的金属原子的结合主要通过以下几种金属物理性质的决定：
#
# 1. **导电性**：
#    金属中电子的自由移动是导电机理的基础。由于金属电子层中的电子与金属核之间的结合较弱，电子可以相对自由地移动，从而使得金属具有良好的导电流性。
#
# 2. 导热性：
#    由于电子在金属中是自由流动的，它们能够迅速地传递热量，因此金属是优秀的热导体。这种特性使得它们在散热器和热交换器等应用中非常有用。
#
# 3.**延展性和塑性（可塑性和延性）**:
#    在受到外力作用时，由于原子间的金属连接较松散，使得原子能够相对容易地重新排列，这使得大多数金属具有出色的延性和可加工性，可以轻松地被拉伸、弯曲或锻造。
#
# 4.  **熔点**和**沸点高**:
#     金属间的结合相对较弱的特性也决定了它们的熔点和沸点多较高。这是因为金属需要克服较少的结合能才能使原子分离，形成液态或气态。<error>然而，实际上金属间的结合较强，需要克服较大的结合能才能使原子分离。</error>
#
# 5.   **密度**高：
#     由于每个金属分子都包含多个金属元素，它们的原子核和电子云相对密集，所以金属通常具有较高的密度。例如，铁的密度约为7.87克/立方厘米，而水密度为1克/cm³。
#
# 6.    **化学活性**低：
#     尽管金属在自然界中通常以单质形式存在，但它们通常不与非金属直接反应，因为金属与大多数非金属性质的原子之间的反应需要较高的能量来克服金属间较低的结合能量。这导致金属化学性质相对稳定。
#
# 7**.电化学稳定性**强：
#    大多数纯金属都具有较强的电化学反应稳定性，这意味着它们不容易被氧化或腐蚀。然而，一些金属，如铁和铝，在特定条件下（如在潮湿环境中）可能会发生腐蚀，这是由于它们与氧气反应形成氧化物。'''
# '''
# 爱德华多（Eduardo）是一位巴西足球运动员，目前效力于<error>英超的埃弗顿队</error>。他在场上担任中场位置，以其出色的控球和传球能力而闻名。'''
#
# '''
# 葡萄牙共和国（Portuguese Republic），简称葡萄牙，是一个位于欧洲西南部的共和制国家。葡萄牙的领土位于伊比利亚半岛西部，拥有大西洋沿岸的一些岛屿。该国东邻西班牙，西、南与<error>非洲的莫桑比克和安哥拉</error>接壤。总面积92,212平方公里，人口约1030万（2022年）。首都里斯本。
#
# 葡语是葡萄牙官方语言，也是世界上最广泛使用的语言之一。大部分居民信奉天主教。历史上，葡萄牙曾是一个重要的海上强国，被称为“航海家”。在15世纪至16世纪期间，葡葡牙探险家和征服者发现了许多新大陆，如巴西、非洲的几内亚湾等地。这使得葡萄牙成为当时世界上最重要的贸易和文化交流中心之一，被誉为“陆地上的海上帝国”（Empire on Land）
# 。然而，随着时间的推移，国家的实力逐渐减弱，直至2
# '''
# '''
# 托倫市（Toruń）是波兰西北部的一个历史悠久的城市，拥有许多受欢迎的旅游景点。以下是一些建议的旅游元素：
#
# 1. 历史建筑：托爾斯泰因（<error>Tolls Tein</error>）是一座著名的桥梁，连接了城市的两个部分。附近的圣约翰教堂（St. John's Church）和圣母玛利亚教堂 (Church of the Assumption of Our Lady) 都是哥特式建筑的典范。
# 2. 老城：漫步在托魯市的古老街道上，欣赏古老的建筑和迷人的小巷。这里还有许多咖啡馆、餐厅和商店供游客享受。
# 3. 中世纪市场广场：市场喷泉（Market Fountain）位于市中心的市场广场（Rynek），是游客必去的地方。这个喷泉建于14世纪，至今仍在使用。周围还有许多历史建筑和餐馆。
# 4. 日落时分的游船之旅：乘坐游船游览托尔河（<error>River Toruña</error>）是一个很好的体验。在日落时分乘坐游船，观赏美丽的景色和古城的迷人光影。
# 5. 白鹳节：每年夏季，托鲁市都会举办白鹳艺术节，庆祝这些美丽的鸟类。游客可以观看表演、音乐会，还可以参观白鸛博物馆。
# 6. 大教堂：圣雅各布大教堂(St James' Cathedral) 是托尔斯泰茵的标志性建筑之一，也是波兰最美丽的教堂之一。这座哥特的红砖建筑值得一游。
# 7. 西贝柳斯纪念馆：芬兰著名作曲家让·西贝流士（Jean Sibelius）在1890年代曾在托卢恩学习音乐。为了纪念他，这座城市设立了一个纪念馆，展示了他的生平和作品。
# '''
# '''
# 分娩分为三个主要阶段：宫颈扩张期、宫颈完全扩张期和胎盘娩出期。以下是每个阶段的详细描述：
#
# 1. 宫颈扩长期（第一阶段）：这个阶段通常需要12-20小时，但时间因个体而异。在这个阶段，子宫开始收缩以帮助胎儿通过产道。这些宫缩被称为阵痛或宫縮。随着宫颈的扩张，宫口从紧闭状态逐渐开到全开（10厘米）。医生或助产士会定期检查宫颈的长度，以确保进展正常。在宫颈扩大期，医生可能会建议产妇改变姿势、走动或使用呼吸技巧来减轻疼痛和加速宫颈开放。
#
# 2.宫颈完成扩张（第二阶段）: 当宫颈全开时，胎儿的头开始通过骨盆进入产道的第二段过程。这被称为"全宫颈"，通常发生在阵痛的最后一个阶段。当胎儿头部通过盆腔时,可能会出现轻微的阻力感，这是正常的。助產士将密切監控這一過程，確保胎兒順利通過並避免產程中出現任何問題。此階段可能需要幾小時，具體時間依個人情況而定。 助產士可能會建議产妇在這個階段的某些時候放鬆肌肉，以便胎頭更容易通过。此外，助产学上可能还会使用一些工具和技术来帮助胎儿顺利出生，例如使用真空吸尘器辅助分娩(<error>vacuum extraction</error>)或者产钳(<error>forceps</error>)。
# 3.胎盘分娩期(第三阶段): 在胎儿出生后，胎盘会与子宫壁分离并排出体外。这个过程通常在胎儿出生后的5-15分钟内完成。有时，医生和护士会用按摩子宫的方法来帮助胎盘排出。如果胎盘不能自行排出，他们可能会进行人工剥离。在整个过程中，医护人员会密切关注母亲和新生儿的状况，确保一切正常，并在产后提供必要的护理和支持。
# '''
# '''
# 卢德里亚那（Ludhiana）是印度旁遮普邦的一个城市，位于<error>印度河沿岸</error>。它是印度最大的城市之一，也是世界上人口最稠密的城市之一。卢德亚娜市的地理位置具有以下特点：
#
# 1. 地理位置：卢德尔亚那是印度北部旁盖普地区的一个重要城市。它位于<error>喜马拉雅山脉和恒河之间的印度河流域</error>。这个地区拥有丰富的农业资源，因此卢尔德亚南被认为是印度的“谷物盆”。
# 2. 大都市区：作为印度北部的工业和商业中心，卢德斯亚内拥有庞大的大都市地区。该地区的工业包括纺织、钢铁、机械、电子和食品等。此外，该市还拥有许多跨国公司的生产基地。这些公司包括福特、丰田、索尼等，为当地创造了大量的就业机会。
# 3.气候：由于地处<error>印度河西岸</error>，鲁德雅纳的气候属于半干旱气候。夏季炎热潮湿，冬季凉爽干燥。每年的降雨量约为640毫米，主要集中在6月至9月之间。
# 4.交通：鲁迪雅那位于连接印度东西南北的交通要道上。印度国家高速公路（NH-1）穿过这座城市，将新德里与印度港口城市孟买相连。另外，印度铁路网也覆盖了整个城市及其周边地区，使其成为印度北方的交通枢纽。
# '''
# '''
# 修 辞 学 汉 语 词 源 ： 《 说 文 解 字 》 谓 顺 事 理 也 。 许 慎 注 ； 言 者 尚 合  以 己 意 ， 受 而 答 之 必 依 所 授 以为 应 指 故 曰 相 饰 同 又 如 「 诬 」 古 亦 作 『 宛 』 假 借 切 兪 音 通 诈 狡 反 覆 不 忠 謂 為 侮 屈 或 訓 引 申 出 使 口 舌 工 巧 技 藝 於 交 際 活 动 中 取 得 优 势 的 方 法 艺 术 本 义 释 读 形 容 物 体 互 助 成 功 用 象 声 名 称 由 来 据 传 远 古人 类 时 期 结 群 居 生 存 需 要 共 他 人 进 行 经 常 的交涉 因 此 就 发 现 了 怎 样 才 能 把 自 己 的 意 图 表 述 明 确 让 听 到 的 人 易 于 领 悟 的 问 题 这 些 问 题 被 历 史 上 的 有 识 士 子 探 讨 并 创 造 了 一 种 专 门 研 究 运 思 维 、 构 句 式 提 语言 技 巧 的 学 说 —— 论 辩 家 们 还 制 定 下 几 乎 无 数 的 修 辞 格 局 供 其 操 纵 随 后 便 逐 步 分 化 演 变 成 为 独 立 的 一 科 目 即 今 代 叫 做 著 作 文 学 的 典 籍 － ─ 诸 多
# '''
# '''
# 和平号的结构主要包括以下几个部分：
# 1. 核心舱（Core Module），这是和平站的指挥中心和生命维持系统。它包括居住舱、服务舱和工作舱。
# 2. 多用途实验室模块（Multipurpose Laboratory Module, MLM）或基本科学实验室（Basics Science Module，BSM)，用于进行科学研究。这个模块包含了多个实验舱，如微重力科学实验设施、材料科学试验设施等。
# '''
# 《美国派》系列、《欧洲性旅行》等。
# '''
# 《惩罚者》（The Punisher）是一部基于漫威漫画角色惩罚者和Marvel Comics同名系列改编的美国电视剧。该剧讲述了退伍军人弗兰克·卡特（Frank Castle，由<error>杰森·奥玛拉</error>饰演）在妻子和孩子们被黑帮杀害后，如何变成一名复仇者，向罪犯寻求正义的故事。
#
# 第一季主要围绕着<error>弗朗哥·卡斯尔</error>如何从一场悲剧性的家庭谋杀案中恢复过来，并展开了一场针对那些导致这场悲剧的罪犯的复仇行动。在这个过程中，他与其他退伍军人、执法官员以及一些神秘的敌人展开了激烈的斗争。最终，<error>弗郎哥</error>发现了一个更大的阴谋，这个阴谋涉及到美国政府的最高层。在第一季的结局，惩罚者在一场激战中杀死了幕后黑手，但同时也暴露了自己的身份，使他的生活变得更加危险。'''
#
# ''' 红牛球场（Red Bull Arena）是奥地利萨尔茨堡的一座现代化多功能体育场馆，位于城市南部的里希特霍夫区（Richtersberg）。这座体育场由红<error>bull</error>公司所有，主要用于足球比赛，特别是为萨爾斯堡紅牛足球俱樂部（Salzburg Red Bull）的比赛提供场地。
#
# 红<error>bull</error>球场于2003年开始建设，于次年正式启用，可容纳30,685名观众。它的设计风格现代且独特，拥有一个全封闭的顶棚，可以在恶劣天气条件下进行比赛。球场内设施齐全，包括更衣室、媒体中心、餐饮区以及VIP包厢。此外，它还举办过音乐会和其他大型活动。
#
# 由于其优秀的设施和地理位置，红<error>Bull</error>球场已经成为萨尔回响全球的标志性建筑之一，并且经常吸引来自世界各地的球迷前来参观和观看比赛。
#
# 总之，萨克斯堡红<error>Bull</error>体育场是一座现代化的体育设施，是萨阿尔斯布尔足球俱乐部的重要主场，同时也是萨市文化和体育活动的重要场所。'''
# '''
# 美国说歌唱作人、歌手和制作人钱斯的奖项包括：2019年MTV音乐录像带大奖最佳新人提名；<error>2108年</error>Soul Train音乐奖最具潜力新人男歌手获奖。
# '''
# '''
# 【分析】力是物体对物体的作用，力的分类有多种，按力的性质分，有重力、电场力，<error>磁 field force</error>，弹力等；按效果分有拉力提力支持力压力向心力等．【解析】力的效果是多种多样的，但无论是哪种效果，都只与两个力有关，一个是施力物体，另一个是受力 物体．所以力的作用是相互的，即一个力必然涉及两个物体：一个是作用（或推、或拉、被举起、加速、发生形变等）的物体；另一个是被作用 （或受推的、受拉的、举起的、减速的等）；而且这两个物体同时表现为力的施与者和受与者．
# 力按性质可分为重力和弹力和按作用可分为拉力和推力等等．力有接触力和场力和按照效果可以分为动力和阻力．按产生的原因分可分为万有引力、电磁力．故答案为：重力的力；弹力的力和；电力的和；磁力的；场力的．'''
#
# ''' 癫痫病真真在通过利用植物资源、适应各种环境和繁殖策略来生存和传播。<error>癫痫</error>病<error>真真</error>应为“白粉菌”。'''
#
# Corrected and marked passage:
# ''' 白粉病菌门（Pucciniales）的真核生物，通常被称为白霉菌或白菌，是一种广泛存在于植物上的寄生菌。它们以孢子的形式传播，并通过以下方式在宿主植物上生存：
#
# 1. **侵染过程**：白粉末状的白霜是由白膜孢（uredospores）和白锈孢(ascospore)组成的。当孢粒落在植物表面时，它们会寻找适宜的环境条件，如湿度、温度和营养。
#
# 2.  **萌发与侵入**：
#    - **白薄膜孢**（Uredosporangium）：这些孢囊在适宜条件下萌发出菌丝，形成称为白点或粉状物的病斑。菌丝丝体穿透植物表皮，进入植物组织。
#    – **性孢产生**: 在一些物种中，白片层下会产生另一种类型的孢体，即白绒毛状（teliospores），它们是无性繁殖的后代，可以在环境中存活一段时间。
#
# 3.   **营养获取**:
#    百粉真茵通过分解植物细胞壁和组织来获取营养。在某些情况下，如果植物死亡，真菇也会分解死亡组织。<error>百粉真茵</error>应为“白粉菌”。
#
# 4.    **繁殖** : 癌细胞在植物内部生长并产生新的孢母细胞，这些细胞可以产生更多的孢粉，继续感染其他部位或传播到其他植物。<error>癌细胞</error>应为“白粉菌细胞”。
#
# 5.     **耐受性** ：白粉尘菌具有一定的耐寒性和耐旱性，能在低温和干燥的环境下存活，等待适宜条件再次侵袭。
#
# 6.      **抗性机制** 部分植物对白面粉菌有一定的抵抗力，例如产生抗真素或其他化学物质来抵御病害。
#
# 总之， 白粉菌通过利用植物资源、适应各种环境和繁殖策略来生存和传播。'''
# [INSP]脑瘫的病因有哪些? [/[INP] ] [INS]1. 遗传因素： ①染色体异常：如先天性愚型、先天性的肌萎缩、小头畸形、染色体脆性综合征等。 ②基因突变：线粒体DNA突变、单基因缺陷、多基因遗传等，如脊髓性肌营养不良、肝豆状核变性、亨廷顿舞蹈病、肌强直性营养不良等 ③基因多态性：某些基因的变异，可导致脑损伤的易感性增加，或使脑组织对缺氧缺血等损伤因素的敏感性增加。 [I]2. [/I]产前因素 ：①宫内感染：风疹病毒、巨细胞病毒等可引起胎儿脑发育障碍。②宫腔内缺氧：胎儿宫内的缺氧，是引起脑缺氧性损伤的主要原因。③母体因素，母体的某些疾病，药物、毒物、放射线等均可影响胎儿大脑的发育。④胎盘因素。⑤胎儿因素:胎儿畸形，胎儿缺氧、胎儿窘迫等 [II]3. II]围产期因素 [III]：早产、过期产，产程延长，难产等均易引起新生儿缺氧。[IV]4. IV]出生后因素[V]，包括新生儿窒息、新生儿缺血症、缺氧症、颅内出血、感染、外伤、中毒、营养不良及代谢障碍等[VI]。
# [INSPIRE]【脑神经发育迟缓】
# 【病因】：
# 1、遗传代谢病：染色体畸变、基因异常、代谢异常等；
# 2、围生期异常；如早、中、晚期流产、早破水、胎膜早剥、前置胎盘的胎位异常，脐带绕颈、脐绕身、绕手、羊水过少、过氧、污染、母子血型不合、妊娠高血压综合征、糖尿病、高脂血症等母患疾病；胎儿发育异常如胎儿水肿、无脑儿、脑积水、脊柱裂、脊膜膨出、死胎、畸形胎等
# 3、产伤：难产的产钳助产或臀位牵引、臀牵引等产科手术；产道损伤、头颅血肿、硬膜下血、蛛网膜血；颅骨骨折、骨折片入脑、血块阻塞脑室、静脉窦、动脉、动静脉瘘等、
# '''
# 【分析】本题考查的知识点是隋唐时期的石窟艺术，识记莫多窟的相关知识．【解答】莫<error>何多</error>佛窟建于<error>685年</error>，是莫哈窟中最早的一座洞窟，第<error>257窟</error>是其中最大的一窟．窟内主佛高达<error>35.5米</error>，两壁有241身飞天，窟顶有5个伎乐天．故答案为：<error>34.2米</error>．
# 故选A．】
#  【点评】掌握莫窟的有关知识，了解莫高的历史地位．
#   【小题2】敦煌莫 窟现存洞<error>329个</error>，壁画<error>4500平方米</error>，彩塑和壁画卷共有<error>2 407身</error>，其中最大的一个高达 <error>36米多</error>，最小的一个只有2厘米．敦煌壁画的绘画内容和手法， 继承了秦汉以来传统的绘画风格，同时又受到了中亚和印度绘画的影响．这些壁 画，不仅具有极高的艺术价值，而且对于研究中外历史、宗教、地理、气象、天文、医药、化学、音乐、舞蹈、雕塑等都有极其重要的参考价值．
# 敦煌 壁画画在洞内四壁、窟頂和佛龛四周围，内容博大精深，有神话故事、佛教故事，也有现实生活的描写．其中以佛教史迹画和经变画占主要地位，其次为神怪、供养人、装饰画等．壁面 绘画，有的用纯金绘成，故有“黄金窟”之称．现藏于英国伦敦博物馆的莫壁《维摩诘经》变，画于公元8世纪，画面用金线勾出轮廓，敷色艳丽，为敦煌画中最精美的作品之一．
# 莫  窟壁画像，继承了中国汉代以来绘画的传统，又吸收了中西亚和印度的绘画技法，形成了独特的艺术风格．莫的壁绘画艺术是我国美术史上的瑰宝，也是世界文化艺术的宝 贵财富．1987年12月，联合国教科文组织将莫列为世界文化遗产之一，1 994年列入世界文化和自然遗产名录．2017 年5月18日，列入《世界遗产预备名册》． [1]  | | |  1 | 2 | [返回首页] [](https'''
#
# ''' 尼日尔利亚的卡兹纳（Katsina）州与其周边的几个州相邻，包括：
#
# 1. 凯杜纳联邦首都区（<error>Federal Capital Territory, Kaduna</error>）
# 2. 哈科特港州（<error>Hausa State</error>）
# 3. 索科托州 （Sokoto State）
# 4. 扎里马州 (Zamfara State)
# 5. 乔斯州(<error>Jos, Plateau State</error>）（在北部边缘，但不直接接邻）
#
# 这些州共同构成了尼北部地区的一部分。'''
# '''
# 国际棋联（FIDE，全称：International Chess Federation）是国际性的国际象棋组织，成立于1924年。它的主要职责如下：
#
# 1. 制定和修改国际棋盘棋规则和标准：国际<error>围棋</error>联合会负责制定和维护国际标准的国际<error>跳棋</error>比赛规则、棋盘尺寸、计时器等。
# 2. 组织国际比赛和活动：Fide负责组织和监管各种级别的国际赛事，如世界冠军赛、大奖赛、洲际锦标赛等，以及推广和国际交流的国际活动。此外，FID还组织一些非正式的比赛和活动，以促进国际间的友谊和交流。例如，它组织了“奥林匹克”团队赛和世界青年锦标赛等活动。
# 3. 发展国际跳跃棋事业：该组织的使命之一是促进和发展国际<error>跃棋</error>运动。为此，他们与各国棋协合作，提供资源和支持，帮助建立新的棋院和提高现有棋院的水平。他们还支持教育和培训项目，以提高棋手的技能和知识。
# 4. 制定国际评级制度：为了公平地比较国际选手的能力，国际联盟制定了国际等级分系统。该系统将棋手的成绩与他们的对手的能力和水平联系起来，为国际比赛的资格和奖金分配提供依据。
# 5. 促进性别平等：fide致力于促进男女在国际<error>跳跃游戏</error>中的平等代表。他们通过实施性别平衡的参赛资格标准、提供培训和奖学金计划等方式来实现这一目标。
# 6. 维护棋类运动的声誉：作为国际性组织,FIE有责任确保国际<error>舞蹈</error>运动的积极形象。这包括监督国际比赛中遵守规则和道德规范，处理运动员和协会之间的纠纷，并确保比赛以透明和公正的方式进行。
# 7. 与其他体育组织合作：与国际奥委会和其他国际体育联合会建立合作关系，共同推动国际体育运动的发展。
# 8. 提供资源和信息：为会员协会和棋友提供有关国际<error>跳舞</error>运动的资源和信息服务，包括规则手册、比赛时间表、新闻通讯等。
# 总之，作为主管国际国际像棋的组织，菲德在制定规则标准，举办国际竞赛，促进棋类项目的发展，提高棋类的声誉等方面发挥着重要作用。
# '''
# '''（） A.  公元前1世纪，为抵御外敌  B. 先前2世纪末，为了商业贸易
#
# B'''
#
# The provided response does not contain any hallucinations based on the definitions provided. Therefore, no tags are necessary.
# '''
# 萨伽法王的称号始于公元1035年，当时西藏萨嘉王朝的建立者昆·果尔多杰被尊奉为第一世萨珈法 王。从那时起，萨噶法王一脉相传，成为藏传佛教中地位崇高的宗教领袖之一。以下是一些关于萨 珈 法 王的著名历史事件的简要概述：
#
# 1. 萨嘎王朝的诞生（11世纪）：昆果多吉建立了萨加王朝，并成为了第一世的萨咖法王王。他的儿子贡却杰布成为了第二世法王大，进一步巩固了萨加的势力。
# 2. 大昭寺的重建（<error>公元978年</error>）: 第一世噶丹赤巴（藏传的四大活佛之一）阿旺却扎在拉萨大昭 寺主持重建工程，这是萨加拉萨王朝的重要贡献之一，也是萨拉王朝与藏地其他教派和政权建立联系的开始。
# '''
# ''' 巧克力糖桨（英语：Chocolate syrup），是一种常见的甜味酱汁，通常用于增添食物的巧克力风味。以下是巧克力酱的一些常见用途：
#
# 1. 咖啡和热饮：在咖啡、拿铁、摩卡或热巧克力中加入巧克力浆，使其具有浓郁的可可味道。
# 2. 冰淇淋和冷冻甜品：作为配料添加到冰淇淋、冰激凌蛋糕、圣代或奶昔中，增加口感和视觉吸引力。
# 3. 面包和糕点：用于涂抹面包、甜甜圈、松饼或蛋糕，为烘焙食品增添巧克力层。
# 4. 水果和麦片：与新鲜水果搭配，如香蕉、草莓或酸奶麦，制作成健康的巧克力水果碗。
# 5. 烘焙：用作蛋糕面糊、饼干或布朗尼的成分，增添深度和巧克力香气。
# 6. 快餐和家庭烹饪：可以用来做巧克力汉堡酱、<error>烤肉酱</error>或者直接倒在炸鸡上，作为调味料。
# 7. 家庭自制糖果：制作巧克力棒、巧克力豆或巧克力涂层的坚果等。
#
# 巧克力甜浆因其多功能性和美味而受到许多人的喜爱，是厨房里常备的调料之一。'''
# ''' 微软海马星（<error>Windows Neptune</error>）是一个虚构的Windows操作系统，它从未被官方开发或发布。然而，如果你指的是类似的概念或假设中的下一代Windows系统，通常这样的操作系统会包含以下一些可能的特色：
#
# 1. **增强的AR/VR支持**：随着技术的发展，可能会有更深入的虚拟现实和增强现实集成，提供沉浸式用户体验。
#
# 2. **量子计算兼容**或**更高级的AI集成**: 随着量子技术和人工智能的进步，操作系统可能会更好地支持这些新兴技术。
#
# 3. 更流畅的界面与设计：可能会采用更加直观、动态和美观的用户界面，以及更高效的多任务处理。
#
# 4. 云集成更深：与Azure等云服务的整合可能更加紧密，实现无缝的云端工作和存储。
#
# 5. 安全性提升：强化安全防护措施，包括更好的隐私保护和防止新型威胁的能力。
#
# 6. 绿色环保：操作系统可能更注重能源效率，减少对环境的影响。
#
# 7. 智能家居控制：可能集成智能家居设备的统一控制中心，方便用户管理家庭设备。
#
# 8. 自适应学习：根据用户的使用习惯和偏好，自动调整设置和推荐功能。
#
# 9. 边缘计算能力**（Edge Computing）**: 提供更快的数据处理和响应速度，尤其是在物联网设备中。
#
# 请注意，这些都是基于现有趋势和想象的推测，并非实际存在的微软产品。真正的下一代操作系统（如Windows 11）会有其官方发布的特性和改进。'''
# '''外交机构是代表国家进行外交活动的机构，根据其性质和职能的不同，可以分为以下几种分类：
# 1. **驻外使馆**：这是国家在外国设立的常驻外交机关，代表本国政府与驻在国进行政治、经济、文化等方面的交流与合作。使领馆通常由大使或领事馆馆长领导，负责处理两国间的官方事务。
# 2. 大使馆：大使馆是驻外国首都的高级外交使团，通常代表一个国家与另一个国家建立外交关系。大使馆通常设有政治处、商务处和文化处等部门，以处理政治事务、促进经济合作和推动文化交流。
#
# 3.**领事机构**（领事办事处、领事处）：领事机关负责本国民众在国外的领事保护和协助，包括颁发旅行证件、协助处理法律事务等。领事官员通常不参与外交谈判，但可以提供有关驻在地法律、文化和商业环境的信息。
#
# 4.  **大使馆和领事机构的联合机构（使领事）**: 在一些国家，大使馆与领事处的职能可能会合并，形成使、领事务合并的机构。这种机构通常会设有外交和领事的部门来分别处理外交事务和提供领事服务。
#
# 5.   **外交代表团**或**使节团** ：这些是临时性的外交组织，由国家派遣到其他国家参加特定活动或进行谈判。代表团通常包括外交官、专家和其他相关人员，其任务可能是参加国际会议、谈判条约或处理紧急外交事件。
#
# 6.    **国际组织代表处** (如联合国、世界贸易组织、国际货币基金组织等)：国家在这些国际组织的代表机关。代表处的任务是促进本国的利益，参与国际事务，并与其他成员国合作解决共同问题。
#
# 7.     **双边或多边外交委员会**和**联络处（联络办事处）/联络组** : 这些机构负责协调和促进国家间的合作，特别是在特定领域（如经济贸易、科技、教育等）。它们通常设在国家首都，但也可能在其他城市或地区设立分支机构以加强与当地利益相关者的联系。
#
# 8.      **特别使** **/ 特使/大使特别代表**/ **特别外交特派团（Special Envoy）或特别大使** / **大使特命全权代表（Ambassador Extraordinary and Plenipotentiary）等**，这些通常是由国家领导人任命，专门负责解决'''
# ''' 斯内德、范德法特、罗本、<error>卢西奥</error>、<error>埃弗拉</error>、库伊特等。'''
# ```
# 使用 Python 的 Flask 框架创建简单的 Web 应用程序非常简单。以下是一个基本的步骤指南，用于创建使用聊天接口的 Flask Web应用程序：
# 1. 安装 Flask。首先，您需要安装 Python Flask。您可以使用pip安装命令来安装Flask。在命令行中运行以下命令：
# <error>pip install FlassK</error>
# <error>pip3 install flask</error>
# ```python
# # 安装 Flask using pip
# !pip install flask
# ```
# 2. 创建 Flask 应用。创建一个新的 Python 文件，并将其命名为 `app.py`。在这个文件中，导入 Flask 库并创建应用程序实例。例如：
# ```python
# from flask import Flask
# app = Flask(__name__)
# ```
# 3. 实现聊天
# ```
# '''
# A. 数学、物理和化学
# B. 天文学和地球科学
# C. 人文学和社会科学（如经济学、政治学等）
# D. A+B+C
# 答案：D
# '''
# '''
# 阿方索·德·阿尔布开克（Afonso de Albuquerque）是葡萄牙的一位著名探险家和军事将领，他在15世纪末和16世纪初的印度洋地区进行了一系列重要的探险和征服活动。他被称为“东方的征服者”，因为他的军事才能和政治手腕使葡萄牙在东印度地区的地位得到了巩固和加强。
#
# 关于<error>阿桑索尔·德拉·奎略（José de Almada Negreiros）</error>的资料相对较少，他是葡萄牙的一名画家和雕塑家，活跃于20世纪初。他的作品受到了象征主义和现代主义的影响，以描绘葡萄牙历史和民间传说为主题。他的画作和雕刻作品在葡萄牙国内和国际上都有很高的评价。
# '''
# '''
# 特嘉丽（TIGER）公司成立于1930年，总部位于日本东京，是一家以生产厨房用具、个人护理用品、清洁用品等产品而闻名于世的日本跨国公司。特<error>迦</error>丽公司的产品线非常广泛，包括但不限于以下几类：
#
# 1. 厨房用品：特<error>加</error>丽以其高质量的厨房工具而著名，如不锈钢削皮器、切菜板、多功能厨房剪刀、食品处理器等。
# 2. 小家电：除了厨房刀具外，特<error>伽</error>丽还生产各种小家电，例如搅拌机、榨汁机等，这些产品通常设计精巧，操作简便。
# 3. 日用品和美容产品：包括各种美容工具，比如电动剃须刀、电动牙刷、美容按摩器等；以及个人卫生用品，像刨皮刀和指甲锉等小工具。
# 4.个人保健产品: 包括按摩器具、足浴盆等放松和保健用品。
# 5.清洁和家居用品: 有各种清洁工具和用品, 如吸尘器,空气净化器以及各种家庭清洁剂等.
# 6.户外用品及运动器材:特<error>特家</error>丽也生产一些户外运动用品如帐篷、背包、钓鱼装备等,以及一些运动健身器材。
# 7.儿童用品与教育玩具: 为儿童设计的玩具和游戏设备。
# 8.宠物用品及其他:包括宠物护理产品、宠物玩具等宠物相关用品以及其它生活辅助用品等等。
# 9.食品和饮料:一些<error>特价丽</error>产品也涉及食品加工和储存，以及饮料制作。
#   10.服装和配饰: 在某些市场，尤其是日本，Tiger也销售一些休闲服装、配飾等时尚产品。
#    11 .办公用品和其他：办公文具，办公家具等办公相关产品，以及其他生活必需品。
#  12 旅游和旅行用品 ：如旅行背包，旅行枕，行李箱等旅游相关商品。
#     13 电子产品：一些与电子产品相关的产品如手机壳，充电器，耳机等配件。
#      14 文娱产品和礼品：各种文房四宝，礼品包装，文玩等文化娱乐产品及礼品。
#       15 其他：还有一些特殊用途的产品，可能包括健康保健品、家居装饰品等其他生活用品。
# '''
# '''
# 巴斯德拉环形山的直径约为18公里，位于月球的正面。它的外观特点是有一个中央峰和两个较小的中央坑。环形山西南部分有一个巨大的悬崖，而东北部分则相对平坦。此外，环形山上还有许多小撞击坑和其他地质特征。
# '''
# '''
# 美国内战（1861-<error>1965</error>）是美国历史上最血腥的战争之一，主要涉及北方联邦政府和南方邦联之间的冲突。堪薩斯內戰是這場大規模戰爭中的一個重要部分，主要是由於堪萨斯州在南北之間的立場不確定，以及該地區的種族和土地問題。
#
# 堪萨克斯的地理位置使其成為美國內战的關鍵地帶。該州位於美加邊境，是南北戰線的連接點。<error>此外，堪萨尔斯還擁有豐富的農業和資源，使其在戰略上變得非常重要。</error>因此，當南北雙方在堪撒斯展開競爭時，該州的命運成爲了戰場上的關键因素。
#  堪塞斯在內战期間持續面臨著種種挑戰，包括土地、種裔和立憲問题。許多堪察斯居民支持南方，認為他們應該有自己的選擇。然而，隨著戰事發展，北方政府開始對堪查斯施加壓力，要求該州政府加入北方。這導致了<error>1755年</error>堪桑斯内戰爆發，南方支持者與北方支持者之聞發生了暴力衝突。
# '''
# '''
# 浙莱是浙江的菜系，其知名莱肴有：
# 1.西湖醋鱼：是杭州的传统名菜，选用西湖中捕捞的草鱼，经烹制后，鱼肉嫩美，带有蟹味，酸甜适口。
# 2.东坡肉：相传是宋代大文学家苏东坡所创制，选料精细，制作考究，色泽红亮，肉质酥软，肥而不腻。3.干炸响铃：选用猪肉丝和笋丝，用薄皮包裹，炸制而成，外脆里嫩，鲜香可口。4.叫化童子鸡：是一道传统的绍兴菜。选用童子的鸡，经过腌制、烘烤而成。外皮酥脆，鸡肉鲜嫩。5.龙井虾仁：以清明节前后采制的龙顶茶烹制的虾菜为名，虾肉鲜美嫩滑，茶香浓郁。6.宁波汤团：宁波的传统小吃，以糯米粉制成皮，内包豆沙、肉丝等馅料，煮熟后软糯香甜。7.绍兴醉鸡 ：绍兴的传统菜品，将整鸡用绍兴老酒、酱油、糖等调料腌制后蒸熟，味道鲜甜，酒香扑鼻。8.咸菜大汤黄鱼 浙江沿海地区的传统名莱，黄鱼的鲜味与咸白菜的咸香相得益彰，汤汁浓郁，风味独特。9.锅烧肉 锅巴肉，是<error>上海</error>的传统莱品。猪肉煮至半熟捞出，锅内留油，放入锅底炸至金黄酥香，再将猪肉放回锅中翻炒，加入调料，出锅前撒上葱花。10.红烧河豚 河鲀，又称河鱼鳃，是一种珍贵的鱼类，主要产于浙江杭州一带，红焖河虱肉味鲜醇，营养丰富。#美食[话题]# #浙['''
# '''
# '''2021年12月，秘鲁斯总统佩德罗·卡斯蒂略宣布，将取消对非法移民的庇护政策，并要求外国移民在2023年6月30日前离开秘魯。
# 2020年，由于新冠疫情，许多秘拉人失去了工作，而秘拉的失业率飙升至10.5%。为了缓解经济压力，政府决定允许外国人在秘拉斯工作。然而，这一政策却导致大量非法外国劳工涌入<error>秘拉特拉</error>，给当地居民带来了诸多不便。因此，卡斯特罗政府在去年12月份宣布取消这一庇佑政策。
#
# 秘卢政府宣布这一决定后，引发了国内民众的强烈不满。他们认为，外国人的涌进导致了当地就业机会的减少，加剧了社会不公。此外，一些非法劳工会利用庇荫政策逃避法律制裁，甚至从事非法活动。这些因素都导致了秘盧民众的不满情绪。20'''
# ''' 玳瑁螺（学名：Archachatina marginata），又称为大丽螺、宝螺，是属于腹足纲<error>宝龟科</error>的一个物种。它们主要分布在非洲的热带地区，包括东非、南非、马达加斯加以及部分西非国家。在这些地区中，它们可以在各种生境中找到，如森林、草原、沼泽和农田等。由于它们的壳具有很高的商业价值，因此在一些地方可能被过度捕捉，导致野生种群数量下降。'''
# '''美国陆医部下辖有：
# 1. 陆军医学部（Army Medical Command）
# 2. **陆军卫生部**（**<error>Armed Forces Medical Center</error>**）：负责陆军的卫生事务，包括医疗、预防医学、卫生教育、健康促进、医疗保障、军事医学研究、医学教育与训练、后勤保障等。
# 3. [INV] **<error>美国军事医学院</error>**：位于华盛顿特区，是美国陆军最高军事医疗教育机构，负责培养陆军高级医疗军官和卫生专业人员。
#
#  4.**陆军综合医疗中心**(Army Integrated Medical Centers)：由陆军总医院、陆军创伤研究所、美国国家军事神经创伤中心、沃尔特·里德国家医学中心和陆军传染病医学研究所组成，主要负责提供综合的医疗服务。
#
#  5.陆军医院（陆军医疗机构）（Military Treatment Facilities）: 包括陆军地区医院和野战医院，提供医疗服务，并负责训练和准备医疗人员。
#
#  6.美国军医队（Medical Corps），由医疗队和医疗营组成。医疗队的任务是提供紧急医疗服务和医疗后送，而医疗营地则提供长期医疗和康复服务以及医疗训练。
#
#  7.医疗后勤司令部（Healthcare Logistics Command，HCLC）负责医疗物资和设备的采购、储存、运输和分配。
#
#  8.军事卫生研究与开发司令部 (MEDCOM) 负责军事卫生的研究和开发，以及军事健康保障系统的评估和改进。
#
#  9.卫生保障司令部：包括卫生后勤、卫勤保障和卫训保障三个部门，分别负责卫生物资的采购和分发、战时医疗支援和训练以及卫生人员的培训和教育。'''
# '''
# A) 速度较慢
# B) 可扩展性较差
# C) 不支持虚拟存储器
# D) I/O操作受限于<error>CPU速度</error>
# 答案: D)
# '''
# '''
# 1. 皇家马德里（Real Madrid）：2009年至<error>210年</error>，2年间帮助球队赢得了两个西甲冠军、一个国王杯冠军和一个欧洲冠军联赛冠军。
# 2. AC米兰（AC Milan）: <error>22年</error>加盟，但表现一般，没有赢得任何荣誉。
# '''

# %%
# Save intermediate results
with open(f"test/{model_name}_tmpplst.jsonl", "w", encoding="utf-8") as f:
    for ele in resp_list:
        f.write(json.dumps(ele) + "\n")

# %%
import re

# Remove soft_labels and hard_labels from input_lst
tmp_list = []
for item in input_lst:
    new_item = {k: v for k, v in item.items() if k not in ["soft_labels", "hard_labels"]}
    tmp_list.append(new_item)

soft_lst = []
# Extract soft labels from the response
for i, ele in enumerate(resp_list):
    soft_labels = []
    model_text = re.findall(r"'''(.*?)'''", ele, re.DOTALL)
    if model_text:
        resp_list[i] = model_text[0]
    tmp_list[i]["hallucination_detection_output"] = resp_list[i]
    
    # Find all soft labels
    matches = list(re.finditer(r"<error>(.*?)</error>", resp_list[i]))
    # Remove <error> tags and calculate new start and end positions
    clean_text = re.sub(r"</?error>", "", resp_list[i])
    tmp_list[i]["model_output_text"] = clean_text
    offset = 0
    for match in matches:
        start = match.start() - offset
        end = match.end() - offset - len("<error></error>")
        soft_labels.append({"start": start, "end": end, "prob": float(1.0)})
        offset += len("<error></error>")
    # print(soft_labels)
    soft_lst.append(soft_labels)


for ele, sl in zip(tmp_list, soft_lst):
    ele["soft_labels"] = sl

with open("test/zhongjian.jsonl", "w", encoding="utf-8") as f:
    for ele in tmp_list:
        f.write(json.dumps(ele) + "\n")

# %%
# Convert soft_labels to hard_labels and append to each item
for item in tmp_list:
    hard_labels = [[label['start'], label['end']] for label in item['soft_labels']]
    item['hard_labels'] = hard_labels

# Check the result
# for item in tmp_list:
#     print(item)

# %%
# Save the result
with open(f"output/{model_name}/{language}_{model_name}_pred.jsonl", "w", encoding="utf-8") as f:
    for item in tmp_list:
        f.write(json.dumps(item) + "\n")

# %%
import subprocess

# Run evaluation
ref_file = f"input_data/{language}.jsonl"
pred_file = f"output/{model_name}/{language}_{model_name}_pred.jsonl"
output_file = f"output/{model_name}/{language}_{model_name}_scores.txt"

def run_evaluation(ref_file: str, pred_file: str, output_file: str):
    command = f"python3 util/score.py {ref_file} {pred_file} {output_file}"
    subprocess.run(command, shell=True)

run_evaluation(ref_file, pred_file, output_file)
